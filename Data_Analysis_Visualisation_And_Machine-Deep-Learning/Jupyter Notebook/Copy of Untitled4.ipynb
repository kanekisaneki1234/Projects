# %%
import pandas as pd

df = pd.read_csv("/Users/owais/Jupyter Notebook/pokemon_data.csv")

# %%
print(df)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison  45      49       49  \
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
# print(df.head(5))

print(df.tail(5))
# Out:
#        #                 Name   Type 1 Type 2  HP  Attack  Defense  Sp. Atk
# 795  719              Diancie     Rock  Fairy  50     100      150      100  \
# 796  719  DiancieMega Diancie     Rock  Fairy  50     160      110      160
# 797  720  HoopaHoopa Confined  Psychic  Ghost  80     110       60      150
# 798  720   HoopaHoopa Unbound  Psychic   Dark  80     160       60      170
# 799  721            Volcanion     Fire  Water  80     110      120      130
#
#      Sp. Def  Speed  Generation  Legendary
# 795      150     50           6       True
# 796      110    110           6       True
# 797      130     70           6       True
# 798      130     80           6       True
# 799       90     70           6       True

# %%
print(df[['Name', 'Generation']][0:5])
# Out:
#                     Name  Generation
# 0              Bulbasaur           1
# 1                Ivysaur           1
# 2               Venusaur           1
# 3  VenusaurMega Venusaur           1
# 4             Charmander           1

# %%
print(df.head(3))
# Out:
#    #       Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def  Speed
# 0  1  Bulbasaur  Grass  Poison  45      49       49       65       65     45  \
# 1  2    Ivysaur  Grass  Poison  60      62       63       80       80     60
# 2  3   Venusaur  Grass  Poison  80      82       83      100      100     80
#
#    Generation  Legendary
# 0           1      False
# 1           1      False
# 2           1      False

# %%
print(df.iloc[2,1])
# Out:
# Venusaur

# %%
# x = 0
# while x>=5:
# for index, row in df.iterrows():
#   print(index+1, row[['Name', 'Legendary']])
  # print(type(index))
  # print(type(row))
# x+=1
columnstoprint = ['Name', 'Legendary']
# for cname in columnstoprint:
y=print(df[columnstoprint][0:7])
print(type(y))
# Out:
#                     Name  Legendary
# 0              Bulbasaur      False
# 1                Ivysaur      False
# 2               Venusaur      False
# 3  VenusaurMega Venusaur      False
# 4             Charmander      False
# 5             Charmeleon      False
# 6              Charizard      False
# <class 'NoneType'>

# %%
# df.loc[df['Type 1']=='Fire']
# sel_col = df.loc[:,(df == ['Fire', 'Ice']).any()]
# print(sel_col)
# selected_columns = df.loc[:, (df == 2).any()]

specific_values = ['Fire', 'Ice']

# Create the condition to check for the specific values in each column
condition = df.isin(specific_values)

# Select columns with specific values using loc and boolean indexing
# selected_columns = df.loc[:, condition.any()]
selected_rows = df.loc[condition.any(axis=1)]

print(selected_rows)
# Out:
#        #                       Name Type 1  Type 2   HP  Attack  Defense
# 4      4                 Charmander   Fire     NaN   39      52       43  \
# 5      5                 Charmeleon   Fire     NaN   58      64       58
# 6      6                  Charizard   Fire  Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire  Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire  Flying   78     104       78
# ..   ...                        ...    ...     ...  ...     ...      ...
# 768  698                     Amaura   Rock     Ice   77      59       50
# 769  699                    Aurorus   Rock     Ice  123      77       72
# 788  712                   Bergmite    Ice     NaN   55      69       85
# 789  713                    Avalugg    Ice     NaN   95     117      184
# 799  721                  Volcanion   Fire   Water   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %%
value1 = 'Fire'
value2 = 'Rock'

# Create the condition to check for the specified values in the column
# condition = (df['Type 1'] == value1) & (df['Type 2'] == value2)

# Get the rows that satisfy the condition using loc and boolean indexing
selected_rows = df.loc[(df['Type 1'] == value1) & (df['Type 2'] == value2)]

# Print the selected rows
print(selected_rows)
# Out:
#        #      Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def
# 237  219  Magcargo   Fire   Rock  50      50      120       80       80  \
#
#      Speed  Generation  Legendary
# 237     30           2      False

# %%
df.sort_values(['Type 1', '#'])
# Out:
#        #        Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def
# 13    10    Caterpie    Bug     NaN  45      30       35       20       20  \
# 14    11     Metapod    Bug     NaN  50      20       55       25       25
# 15    12  Butterfree    Bug  Flying  60      45       50       90       80
# 16    13      Weedle    Bug  Poison  40      35       30       20       20
# 17    14      Kakuna    Bug  Poison  45      25       50       25       25
# ..   ...         ...    ...     ...  ..     ...      ...      ...      ...
# 724  656     Froakie  Water     NaN  41      56       40       62       44
# 725  657   Frogadier  Water     NaN  54      63       52       83       56
# 726  658    Greninja  Water    Dark  72      95       67      103       71
# 762  692   Clauncher  Water     NaN  50      53       62       58       63
# 763  693   Clawitzer  Water     NaN  71      73       88      120       89
#
#      Speed  Generation  Legendary
# ...

# %%
df.sort_values(['Type 1', '#'], ascending = [1,0])
# Out:
#        #                     Name Type 1  Type 2  HP  Attack  Defense
# 734  666                 Vivillon    Bug  Flying  80      52       50  \
# 733  665                   Spewpa    Bug     NaN  45      22       60
# 732  664               Scatterbug    Bug     NaN  38      35       40
# 717  649                 Genesect    Bug   Steel  71     120       95
# 698  637                Volcarona    Bug    Fire  85      60       65
# ..   ...                      ...    ...     ...  ..     ...      ...
# 59    54                  Psyduck  Water     NaN  50      52       48
# 11     9                Blastoise  Water     NaN  79      83      100
# 12     9  BlastoiseMega Blastoise  Water     NaN  79     103      120
# 10     8                Wartortle  Water     NaN  59      63       80
# 9      7                 Squirtle  Water     NaN  44      48       65
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 734       90       50     89           6      False
# ...

# %% [markdown]
# ### **Making Changes to the data**

# %%
# df['Total'] = df['HP'] + df['Attack'] + df['Defense'] + df['Sp. Atk'] + df['Sp. Def'] + df['Speed']
df['Total'] = df.iloc[:,4:10].sum(axis=1)
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    318
# 1       80     60           1      False    405
# 2      100     80           1      False    525
# 3      120     80           1      False    625
# 4       50     65           1      False    309

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison  45      49       49  \
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    318
# ...

# %%
df.drop(columns='Total')
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison  45      49       49  \
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
cols = list(df.columns)
print(cols)
print(len(cols))
df = df[cols[0:10]+[cols[-1]]+cols[10:12]]
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Generation', 'Legendary', 'Total']
# 13

# %%
df
cols = list(df.columns)
print(cols)
print(len(cols))
# Out:
# ['#', 'Name', 'Type 1', 'Type 2', 'HP', 'Attack', 'Defense', 'Sp. Atk', 'Sp. Def', 'Speed', 'Total', 'Generation', 'Legendary']
# 13

# %%
df.head(5)
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Total  Generation  Legendary
# 0       65     45    318           1      False
# 1       80     60    405           1      False
# 2      100     80    525           1      False
# 3      120     80    625           1      False
# 4       50     65    309           1      False

# %%
df.to_csv('modified.csv', index = False)

# %%
df2 = pd.read_csv("/Users/owais/Jupyter Notebook/modified.csv")
print(df2)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison  45      49       49  \
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary
# 0         65       65     45    318           1      False
# ...

# %%
df.to_csv('modified.txt', index = False, sep='\t')

# %%
smol_df = df.loc[(df['Type 1']=='Fire') & (df['Type 2']=='Flying')]
smol_df.reset_index(drop=True, inplace=True)
smol_df
# Out:
#      #                       Name Type 1  Type 2   HP  Attack  Defense
# 0    6                  Charizard   Fire  Flying   78      84       78  \
# 1    6  CharizardMega Charizard Y   Fire  Flying   78     104       78
# 2  146                    Moltres   Fire  Flying   90     100       90
# 3  250                      Ho-oh   Fire  Flying  106     130       90
# 4  662                Fletchinder   Fire  Flying   62      73       55
# 5  663                 Talonflame   Fire  Flying   78      81       71
#
#    Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary
# 0      109       85    100    534           1      False
# 1      159      115    100    634           1      False
# 2      125       85     90    580           1       True
# 3      110      154     90    680           2       True
# 4       56       52     84    382           6      False
# 5       74       69    126    499           6      False

# %%
import re

# df['Status'] = 0
df = df.loc[~df['Name'].str.contains('^Mega[a-z]*')]

# %%
df.loc[df['Total'] >= 550, ['Status']] = 'Good'

df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison  45      49       49  \
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary Status
# ...

# %%
df.loc[df['Name']=='Yanmega']
# Out:
#        #     Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  Sp. Def
# 520  469  Yanmega    Bug  Flying  86      76       86      116       56  \
#
#      Speed  Total  Generation  Legendary Status
# 520     95    515           4      False    NaN

# %%
good_pokemon = df[df['Total']>550]

good_pokemon.head()
# Out:
#      #                       Name  Type 1  Type 2  HP  Attack  Defense
# 3    3      VenusaurMega Venusaur   Grass  Poison  80     100      123  \
# 7    6  CharizardMega Charizard X    Fire  Dragon  78     130      111
# 8    6  CharizardMega Charizard Y    Fire  Flying  78     104       78
# 12   9    BlastoiseMega Blastoise   Water     NaN  79     103      120
# 23  18        PidgeotMega Pidgeot  Normal  Flying  83      80       80
#
#     Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary Status
# 3       122      120     80    625           1      False   Good
# 7       130       85    100    634           1      False   Good
# 8       159      115    100    634           1      False   Good
# 12      135      115     78    630           1      False   Good
# 23      135       80    121    579           1      False   Good

# %%
dualtype = df[(df["Type 1"].isin(['Fairy', 'Steel'])) & (df["Type 2"].isin(['Fairy', 'Steel']))]

dualtype.head()
# Out:
#        #               Name Type 1 Type 2  HP  Attack  Defense  Sp. Atk
# 328  303             Mawile  Steel  Fairy  50      85       85       55  \
# 329  303  MawileMega Mawile  Steel  Fairy  50     105      125       55
# 777  707             Klefki  Steel  Fairy  57      80       91       80
#
#      Sp. Def  Speed  Total  Generation  Legendary Status
# 328       55     50    380           3      False    NaN
# 329       95     50    480           3      False    NaN
# 777       87     75    470           6      False    NaN

# %%
df['Status'].notna()
# Out:
# 0      False
# 1      False
# 2      False
# 3       True
# 4      False
#        ...
# 795     True
# 796     True
# 797     True
# 798     True
# 799     True
# Name: Status, Length: 799, dtype: bool

# %%
legendary = df.loc[df['Legendary']==True]
# legendary = df[df['Legendary']==True]
legendary.head()
# Out:
#        #                 Name    Type 1    Type 2   HP  Attack  Defense
# 156  144             Articuno       Ice    Flying   90      85      100  \
# 157  145               Zapdos  Electric    Flying   90      90       85
# 158  146              Moltres      Fire    Flying   90     100       90
# 162  150               Mewtwo   Psychic       NaN  106     110       90
# 163  150  MewtwoMega Mewtwo X   Psychic  Fighting  106     190      100
#
#      Sp. Atk  Sp. Def  Speed  Total  Generation  Legendary Status
# 156       95      125     85    580           1       True   Good
# 157      125       90    100    580           1       True   Good
# 158      125       85     90    580           1       True   Good
# 162      154       90    130    680           1       True   Good
# 163      154      100    130    780           1       True   Good

# %%
df.head()
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65  \
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Total  Generation  Legendary Status
# 0       65     45    318           1      False    NaN
# 1       80     60    405           1      False    NaN
# 2      100     80    525           1      False    NaN
# 3      120     80    625           1      False   Good
# 4       50     65    309           1      False    NaN

# %%
out = "Hello"
are = list[out]
print(are)
# Out:
# list['Hello']

# %%
 # df.drop(columns=['Generation','Total'])
# (df.groupby(['Type 1', 'Type 2'])).loc[lambda df:df[cols[0:11]+cols[12:13]]].sum(numeric_only=True)
df = df[cols[0:11]+cols[12:13]]
(df.groupby(['Type 1', 'Type 2'])).sum(numeric_only=True)
# Out:
#                     #   HP  Attack  Defense  Sp. Atk  Sp. Def  Speed  Total
# Type 1 Type 2
# Bug    Electric  1191  120     124      110      154      110    173    791  \
#        Fighting   428  160     310      190       80      200    160   1100
#        Fire      1273  140     145      120      185      160    160    910
#        Flying    4008  882     982      862     1020      967   1160   5873
#        Ghost      292    1      90       45       30       30     40    236
# ...               ...  ...     ...      ...      ...      ...    ...    ...
# Water  Ice        309  270     250      340      240      235    200   1535
#        Poison     356  185     205      175      185      275    255   1280
#        Psychic    559  435     365      520      470      395    220   2405
#        Rock      1720  283     331      451      246      260    144   1715
#        Steel      395   84      86       88      111      101     60    530
#
#                  Legendary
# ...

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison  45      49       49  \
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total  Legendary
# 0         65       65     45    318      False
# ...

# %%
df['Status']='Not so good'
# Out:
# /var/folders/m7/9y8yxtsj0g95rl866wh70mb80000gn/T/ipykernel_63061/1110418352.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Status']='Not so good'

# %%
# df['Status']=df['Statfus'].where(df['Total']<=550, other='Good')

# %%
df.loc[df['Total']>=550, "Status"] = "Good"

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison  45      49       49  \
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total  Legendary       Status
# 0         65       65     45    318      False  Not so good
# ...

# %%
# df.drop(['Status'], axis=1)
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison  45      49       49  \
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total  Legendary
# 0         65       65     45    318      False
# ...

# %%
crisis = pd.Series([100, 500], index= ['Totl', 'Sped'])

# %%
df[['Speed','Total']]+crisis
# Out:
#      Sped  Speed  Total  Totl
# 0     NaN    NaN    NaN   NaN
# 1     NaN    NaN    NaN   NaN
# 2     NaN    NaN    NaN   NaN
# 3     NaN    NaN    NaN   NaN
# 4     NaN    NaN    NaN   NaN
# ..    ...    ...    ...   ...
# 795   NaN    NaN    NaN   NaN
# 796   NaN    NaN    NaN   NaN
# 797   NaN    NaN    NaN   NaN
# 798   NaN    NaN    NaN   NaN
# 799   NaN    NaN    NaN   NaN
#
# [799 rows x 4 columns]

# %%
df
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense
# 0      1              Bulbasaur    Grass  Poison  45      49       49  \
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Total  Legendary       Status
# 0         65       65     45    318      False  Not so good
# ...
